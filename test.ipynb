# %%
import pandas as pd
import random
import numpy as np
import os
import tensorflow as tf
import cv2
from tensorflow import keras
from tensorflow.keras import *
from tensorflow.keras.models import Sequential, Model
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
plt.figure(figsize=(20,20))

img_folder=r'fabrics\\Fabrics\\Acrylic'
for i in range(5):
    file = random.choice(os.listdir(img_folder))
    image_path = os.path.join(img_folder, file)
    img=mpimg.imread(image_path)
    ax=plt.subplot(1,5,i+1)
    ax.title.set_text(file)
    plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-37-0b7b2ea09cad> in <module>
#       5 img_folder=r'fabrics\\Fabrics\\Acrylic'
#       6 for i in range(5):
# ----> 7     file = random.choice(os.listdir(img_folder))
#       8     image_path = os.path.join(img_folder, file)
#       9     img=mpimg.imread(image_path)
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: 'fabrics\\\\Fabrics\\\\Acrylic'

# %%
IMG_WIDTH = 200
IMG_HEIGHT = 200
img_folder = r'C:\\Users\\ukida\Desktop\\3학년 2학기\\데이터사이언스응용\\팀프로젝트\\Untitled Folder\\fabrics\\archive\\seg_train\\seg_train'

# %%
def create_dataset(img_folder):

    img_data_array = []
    class_name=[]

    for dir1 in  os.listdir(img_folder):
        for file in os.listdir(os.path.join(img_folder, dir1)):

            image_path = os.path.join(img_folder, dir1, file)
            image = cv2.imread(image_path, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
            image = np.array(image)
            image = image.astype('float32')
            image /= 255
            img_data_array.append(image)
            class_name.append(dir1)

    return img_data_array, class_name

img_data, class_name = create_dataset(r'archive\\seg_train\\seg_train')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-ec54da09efda> in <module>
#      18     return img_data_array, class_name
#      19
# ---> 20 img_data, class_name = create_dataset(r'archive\\seg_train\\seg_train')
#
# <ipython-input-33-ec54da09efda> in create_dataset(img_folder)
#       8
#       9             image_path = os.path.join(img_folder, dir1, file)
# ---> 10             image = cv2.imread(image_path, cv2.COLOR_BGR2RGB)
#      11             image = cv2.resize(image, (IMG_HEIGHT, IMG_WIDTH), interpolation = cv2.INTER_AREA)
#      12             image = np.array(image)
#
# KeyboardInterrupt:
